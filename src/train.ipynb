# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
df=pd.read_csv("../data/cleaned_data.csv")
x=df.drop("charges",axis=1)
y=df["charges"]

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)
model=RandomForestRegressor(n_estimators=100,max_depth=5,random_state=42)
model.fit(x_train,y_train)
prediction=model.predict(x_test)
print(prediction)
# Out:
# [ 9965.20619872  5922.19909415 27046.25577488 10363.98628458
#  35005.39648716  6846.79956961  2376.60344598 14197.64238451
#   6372.79320138 11064.30750462 19887.06650531  7015.23243564
#   5670.06051975 44388.79754829 46600.88309148 44298.80337471
#  10846.18656851 43872.61257786  9640.30526915 25879.35734737
#   6266.45854887  9109.69105018  2538.81688967  4134.3269078
#  11424.36990855 12704.68278133 13884.9148955   6050.00297965
#  11058.23767596  2552.07891434  7557.34488186 12584.12488587
#   2876.40926446  6706.38986812  5671.74214141 10176.7462977
#   3956.4796448   9240.83546759 24432.92036752 41139.214349
#   5666.75384845  4394.8874022  12587.08596138 13931.67683733
#   6367.845967   15096.05512059  5799.22623562  5736.80980287
#  43014.58342006  6030.83714502 14250.48069169  3821.55308524
#   6805.43082182  2968.79491399 12709.09750021 11724.9986752
#   5198.62532092 44105.64682553 12429.86293222 12701.37638726
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("R² Score:", r2_score(y_test, prediction))
print("MAE:", mean_absolute_error(y_test, prediction))
print("RMSE:", np.sqrt(mean_squared_error(y_test, prediction)))
# Out:
# R² Score: 0.8691729702929302
# MAE: 2608.9122480642077
# RMSE: 4506.742771321562

# %%
print(y.mean())
# Out:
# 13270.422265141257

# %%
# In teeno ko ek sath dekho
print(f"R²: {r2_score(y_test, prediction):.3f}")
print(f"MAE: {mean_absolute_error(y_test, prediction):.2f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, prediction)):.2f}")

# Comparison ke liye
print(f"Target Mean: {y_test.mean():.2f}")
print(f"Target Std: {y_test.std():.2f}")

# Error percentage
mae_percentage = (mean_absolute_error(y_test, prediction) / y_test.mean()) * 100
print(f"MAE as % of mean: {mae_percentage:.1f}%")
# Out:
# R²: 0.869
# MAE: 2608.91
# RMSE: 4506.74
# Target Mean: 12968.32
# Target Std: 12483.20
# MAE as % of mean: 20.1%
